# %%
#Kaggle tutorial :

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()     #pandas adds  custom convertors for matplotlib dictionary.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  #this function helps us to display our plot within jupyter notebook itself and not on the other window.

# %%
import seaborn as sns   #Seaborn is a Python data visualization library based on matplotlib. 
                         #It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
print("Setup Complete")
# Out:
# Setup Complete

# %%
df=pd.read_csv("covid_19_india_dataset.csv")    #reading csv dataset

# %%
df.head(1)    #dispalying limited number of rows by df.head( )
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0               1             KL-TS-P1     30/01/2020                   NaN
#
#   Age Bracket Gender Detected City Detected District Detected State  \
# 0          20      F      Thrissur          Thrissur         Kerala
#
#   State code Current Status                 Notes  \
# 0         KL      Recovered  Travelled from Wuhan
#
#   Contracted from which Patient (Suspected) Nationality Type of transmission  \
# 0                                       NaN       India             Imported
#
#   Status Change Date                                           Source_1  \
# 0         14/02/2020  https://twitter.com/vijayanpinarayi/status/122...
#
#                                             Source_2 Source_3  \
# 0  https://weather.com/en-IN/india/news/news/2020...      NaN
#
#          Backup Notes
# 0  Student from Wuhan

# %%
df=df.drop(['Nationality'],axis=1)               #dropping nationality column from dataframe
df=df.drop(['Estimated Onset Date'],axis=1)
df=df.drop(['Contracted from which Patient (Suspected)'],axis=1)
df=df.drop(['Source_1'],axis=1)
df=df.drop(['Source_2'],axis=1)
df=df.drop(['Source_3'],axis=1)
df.head(2)
# Out:
#    Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0               1             KL-TS-P1     30/01/2020          20      F
# 1               2             KL-AL-P1     02/02/2020         NaN    NaN
#
#   Detected City Detected District Detected State State code Current Status  \
# 0      Thrissur          Thrissur         Kerala         KL      Recovered
# 1     Alappuzha         Alappuzha         Kerala         KL      Recovered
#
#                   Notes Type of transmission Status Change Date  \
# 0  Travelled from Wuhan             Imported         14/02/2020
# 1  Travelled from Wuhan             Imported         14/02/2020
#
#          Backup Notes
# 0  Student from Wuhan
# 1  Student from Wuhan

# %%
df.dtypes #finding the types of each column|
# Out:
# Patient Number           int64
# State Patient Number    object
# Date Announced          object
# Age Bracket             object
# Gender                  object
# Detected City           object
# Detected District       object
# Detected State          object
# State code              object
# Current Status          object
# Notes                   object
# Type of transmission    object
# Status Change Date      object
# Backup Notes            object
# dtype: object

# %%
df['Date Announced']=pd.to_datetime(df['Date Announced']).dt.strftime('%d-%m-%Y')#converting data and time column to date time type.
df['Status Change Date']=pd.to_datetime(df['Status Change Date']).dt.strftime('%d-%m-%Y')

# %%
df.set_index('Patient Number').head(2)
# Out:
#                State Patient Number Date Announced Age Bracket Gender  \
# Patient Number
# 1                          KL-TS-P1     30-01-2020          20      F
# 2                          KL-AL-P1     02-02-2020         NaN    NaN
#
#                Detected City Detected District Detected State State code  \
# Patient Number
# 1                   Thrissur          Thrissur         Kerala         KL
# 2                  Alappuzha         Alappuzha         Kerala         KL
#
#                Current Status                 Notes Type of transmission  \
# Patient Number
# 1                   Recovered  Travelled from Wuhan             Imported
# 2                   Recovered  Travelled from Wuhan             Imported
#
#                Status Change Date        Backup Notes
# Patient Number
# 1                      14-02-2020  Student from Wuhan
# 2                      14-02-2020  Student from Wuhan

# %%
# Set the width and height of the figure
fig, ax = plt.subplots(figsize=(20,10))

# scatter chart showing how virus came vs when it came 
sns.scatterplot(x='Date Announced',y="Type of transmission",data=df,ax=ax,label='Type of Transmission')
sns.scatterplot(x='Date Announced',y="Detected State",data=df,ax=ax,label='Detected State')

# rotate and align the tick labels so they look better
fig.autofmt_xdate()

# Add title to plot
plt.title("Rise of COVID'19 over time")
# Out:
# Text(0.5, 1.0, "Rise of COVID'19 over time")

# %%
df.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Age Bracket', 'Gender', 'Detected City', 'Detected District',
#        'Detected State', 'State code', 'Current Status', 'Notes',
#        'Type of transmission', 'Status Change Date', 'Backup Notes'],
#       dtype='object')

# %% [markdown]
# Trends - A trend is defined as a pattern of change.
# sns.lineplot - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# Relationship - There are many different chart types that you can use to understand relationships between variables in your data.
# sns.barplot - Bar charts are useful for comparing quantities corresponding to different groups.
# sns.heatmap - Heatmaps can be used to find color-coded patterns in tables of numbers.
# sns.scatterplot - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
# sns.regplot - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
# sns.lmplot - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
# sns.swarmplot - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
#
#
# Distribution - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
# sns.distplot - Histograms show the distribution of a single numerical variable.
# sns.kdeplot - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
# sns.jointplot - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.
